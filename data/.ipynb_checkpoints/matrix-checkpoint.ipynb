# %%
#!/usr/bin/python3
import pandas as pd

# %%
! ls
# Out:
# JSON-NET.ipynb       matrix.ipynb         red-iniciativas.xlsx
# edges.csv            nodes.csv            red.json

# %%
df = pd.read_excel('red-iniciativas.xlsx', sheetname=0)
df.head()
# Out:
#                           Visual Properties Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# Vertex 1     Vertex 2                 Color      Width      Style    Opacity
# L2           DICTUC                     NaN        NaN        NaN        NaN
# L1           Gourmet Ltda               NaN        NaN        NaN        NaN
# DICTUC       Dueik                      NaN        NaN        NaN        NaN
# SUNENERGREEN UConcepción                NaN        NaN        NaN        NaN
#
#                            Unnamed: 4 Labels        Unnamed: 6  \
# Vertex 1     Vertex 2      Visibility  Label  Label Text Color
# L2           DICTUC              show    NaN               NaN
# L1           Gourmet Ltda        show    NaN               NaN
# DICTUC       Dueik               show    NaN               NaN
# SUNENERGREEN UConcepción         show    NaN               NaN
#
#                                 Unnamed: 7  Graph Metrics Do Not Edit  \
# Vertex 1     Vertex 2      Label Font Size  Reciprocated?          ID
# L2           DICTUC                    NaN            NaN           3
# L1           Gourmet Ltda              NaN            NaN           4
# DICTUC       Dueik                     NaN            NaN           5
# SUNENERGREEN UConcepción               NaN            NaN           6
#
#                                 ...                    Other Columns  \
# Vertex 1     Vertex 2           ...        Add Your Own Columns Here
# L2           DICTUC             ...                              NaN
# L1           Gourmet Ltda       ...                              NaN
# DICTUC       Dueik              ...                              NaN
# SUNENERGREEN UConcepción        ...                              NaN
#
#                               Unnamed: 12       Unnamed: 13 Unnamed: 14  \
# Vertex 1     Vertex 2              Código          Relación   Categoría
# L2           DICTUC         15VEIPE-48042     15VEIPE-48042           1
# L1           Gourmet Ltda   15L1FPE-48028     15L1FPE-48028           1
# DICTUC       Dueik          15VEIPE-48042   15VEIPE-48042AM           1
# SUNENERGREEN UConcepción   16CONTEC-67391  16CONTEC-67391 C           1
#
#                                    Unnamed: 15          Unnamed: 16  \
# Vertex 1     Vertex 2              Start\nTime            End\nTime
# L2           DICTUC        2016-01-01 00:00:00  2018-01-01 00:00:00
# L1           Gourmet Ltda  2016-01-01 00:00:00  2016-07-01 00:00:00
# DICTUC       Dueik         2016-01-01 00:00:00  2018-01-01 00:00:00
# SUNENERGREEN UConcepción   2016-10-01 00:00:00  2018-10-01 00:00:00
#
#                                  Unnamed: 17  \
# Vertex 1     Vertex 2      Duración\n(meses)
# L2           DICTUC                       24
# L1           Gourmet Ltda                  6
# DICTUC       Dueik                        24
# SUNENERGREEN UConcepción                  24
#
#                                                                  Unnamed: 18  \
# Vertex 1     Vertex 2                                     Nombre\nIniciativa
# L2           DICTUC        Escalamiento y automatización de proceso de pr...
# L1           Gourmet Ltda  Desarrollo de yogurt vegetal basado en desecho...
# DICTUC       Dueik         Escalamiento y automatización de proceso de pr...
# SUNENERGREEN UConcepción   Desarrollo De Nueva Alternativa De Refrigeraci...
#
#                               Unnamed: 19     Unnamed: 20
# Vertex 1     Vertex 2      Vertex 1 Group  Vertex 2 Group
# L2           DICTUC                     7               5
# L1           Gourmet Ltda             NaN             NaN
# DICTUC       Dueik                    NaN             NaN
# SUNENERGREEN UConcepción              NaN             NaN
#
# [5 rows x 21 columns]

# %%
tables = ['Table 1','Table 4','Table 7','Table 10','Table 13','Table 16']

oea = ['Argentina','Bolivia (Plurinational State of)','Brazil','Chile','Colombia','Costa Rica','Cuba','Dominican Republic','Ecuador','El Salvador','Guatemala','Haiti','Honduras','Mexico','Nicaragua','Panama','Paraguay','Peru','United States of America','Uruguay','Venezuela (Bolivarian Republic of)','Barbados','Trinidad and Tobago','Jamaica','Grenada','Suriname','Dominica','Saint Lucia','Antigua and Barbuda','Saint Vincent and the Grenadines','Bahamas','Saint Kitts and Nevis','Canada','Belize','Guyana']

for table in tables:
    xls = pd.ExcelFile('UN_Migration.xlsx')
    df = xls.parse(table, header=0, skiprows=15)
    df.rename(columns={'Unnamed: 0': 'N°', 'Unnamed: 1': 'Destination', 'Unnamed: 2': 'Notes', 'Unnamed: 3': 'Country code', 'Unnamed: 4': 'Type'}, inplace=True)
    df1 = df.set_index('Destination')
    df2 = df1.loc[oea,oea]
    if (table == 'Table 1'):
        df2.insert(0, 'periodo', 1990)
        df2.to_csv('1990.csv', encoding='utf-8')
        pass
    elif (table == 'Table 4'):
        df2.insert(0, 'periodo', 1995)
        df2.to_csv('1995.csv', encoding='utf-8')
        pass

print(table + ' is Done!')

# %%
# df = pd.read_csv('test.csv', usecols=[0,1,2], names=['A', 'B', 'C'])
# pd.pivot_table(df, index='A', columns='B', values='C')
